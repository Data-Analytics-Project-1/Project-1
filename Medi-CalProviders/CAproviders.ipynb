# %%
import csv
import pandas as pd
import requests
import gmaps

from config import g_key

# %%
caproviderdata = pd.read_csv("Enrolled_Medi-Cal_Fee_For_Service_Provider_File.csv", low_memory=False)
caprovider_df = pd.DataFrame(caproviderdata)

# "C:\Users\Kdw86\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.
# Specify dtype option on import or set low_memory=False.
# has_raised = await self.run_ast_nodes(code_ast.body, cell_name,"

#after warning check and toss invalid numbers (with alphas)
#for i, row in caprovider_df.iterrows():
#    try:
#        row['Provider_Number'] = int(row['Provider_Number'])
#    except:
#        caprovider_df.drop(i, inplace=True)

#caprovider_df.dropna(inplace=True)
#caprovider_df.reset_index(drop=True, inplace=True) 



caprovider_df.head()
# Out:
#             X          Y Provider_Number  NPI_Provider_Number  Owner_Number  \
# 0 -117.370428  34.133257      1003120452         1.003120e+09           1.0
# 1 -117.152090  32.884362      1003121385         1.003121e+09           1.0
# 2 -118.744681  34.288645      1003207002         1.003207e+09           1.0
# 3 -124.142048  40.783220      1003121930         1.003122e+09           1.0
# 4 -117.306377  33.181302      1003122086         1.003122e+09           1.0
#
#    Service_Location_Number           Provider_Legal_Name  \
# 0                      1.0     PETERSON, KIMBERLY OD INC
# 1                      1.0  COUNTRYWIDE MEDICAL SUPPLIES
# 2                      2.0       CHANGE WITHIN REACH INC
# 3                      1.0               ALHARIRI, AHMAD
# 4                      1.0                POLLACK, AARON
#
#   Enrollment_Status_Effective_Dat  Provider_Type_Code  \
# 0          2010/08/02 07:00:00+00                  20
# 1          2011/07/05 07:00:00+00                   2
# 2          2018/07/23 07:00:00+00                  71
# 3          2018/11/27 08:00:00+00                  26
# 4          2010/10/19 07:00:00+00                  13
#
#                              Provider_Type_Code_Desc  ...  \
# 0                                 OPTOMETRISTS (FFS)  ...
# 1  ASSISTIVE DEVICE AND SICK ROOM SUPPLY DEALERS ...  ...
# 2        LICENSED CLINICAL SOCIAL WORKER GROUP (FFS)  ...
# 3                                   PHYSICIANS (FFS)  ...
# 4                       HEARING AID DISPENSERS (FFS)  ...
#
#   Provider_Address_Line_2 Provider_Address_City Provider_Address_State  \
# 0               SUITE 100                RIALTO                     CA
# 1             SUITE 5300A             SAN DIEGO                     CA
# 2                  STE 24           SIMI VALLEY                     CA
# 3                     NaN                EUREKA                     CA
# 4                     NaN             OCEANSIDE                     CA
#
#    Provider_Address_Zip Provider_Address_Latitude  Provider_Address_Longitude  \
# 0             923768071                 34.133257                 -117.370428
# 1             921264240                 32.884362                 -117.152090
# 2             930651224                 34.288645                 -118.744681
# 3             955014736                 40.783220                 -124.142048
# 4             920564522                 33.181302                 -117.306377
#
#   MSSA_ID Tract_ID             File_ ObjectId
# 0    151h    38.01  Fee-for-Service         1
# 1    161o    94.00  Fee-for-Service         2
# 2    240a    79.03  Fee-for-Service         3
# 3      39     6.00  Fee-for-Service         4
# 4    156b   185.17  Fee-for-Service         5
#
# [5 rows x 29 columns]

# %%
caprovider_df = caprovider_df.drop(columns=['X', 'Y', "NPI_Provider_Number", "Owner_Number", 'Provider_Address_Zip',
                                            "Service_Location_Number", "Provider_Legal_Name", 
                                            "Provider_Type_Code", "Provider_License_Number",
                                            "Provider_Specialty_Code", "Out_Of_State_Ind", "Out_Of_State_Desc", 
                                            "Provider_Address_County_Code", "Provider_Address_Attention_Line", 
                                            "Provider_Address_Line_1", "Provider_Address_Line_2", "Provider_Address_State", 
                                            "MSSA_ID","Tract_ID", "File_", "ObjectId","Enrollment_Status_Effective_Dat",
                                            "Provider_Address_City"])

caprovider_df.head()
# Out:
#   Provider_Number                            Provider_Type_Code_Desc  \
# 0      1003120452                                 OPTOMETRISTS (FFS)
# 1      1003121385  ASSISTIVE DEVICE AND SICK ROOM SUPPLY DEALERS ...
# 2      1003207002        LICENSED CLINICAL SOCIAL WORKER GROUP (FFS)
# 3      1003121930                                   PHYSICIANS (FFS)
# 4      1003122086                       HEARING AID DISPENSERS (FFS)
#
#   Provider_Specialty_Code_Desc Provider_Address_County_Code_De  \
# 0               NOT APPLICABLE                  San Bernardino
# 1               NOT APPLICABLE                       San Diego
# 2               NOT APPLICABLE                         Ventura
# 3            Internal Medicine                        Humboldt
# 4               NOT APPLICABLE                       San Diego
#
#    Provider_Address_Latitude  Provider_Address_Longitude
# 0                  34.133257                 -117.370428
# 1                  32.884362                 -117.152090
# 2                  34.288645                 -118.744681
# 3                  40.783220                 -124.142048
# 4                  33.181302                 -117.306377

# %%
targetGroups_df = caprovider_df.loc[(caprovider_df["Provider_Type_Code_Desc"] == "PHYSICIANS GROUP (FFS)") | (caprovider_df["Provider_Type_Code_Desc"] == "PHYSICIANS (FFS)")]
targetGroups_df = targetGroups_df.loc[(caprovider_df["Provider_Address_County_Code_De"] != "UNKNOWN")]
targetGroups_df.head(10)
# Out:
#    Provider_Number Provider_Type_Code_Desc      Provider_Specialty_Code_Desc  \
# 3       1003121930        PHYSICIANS (FFS)                 Internal Medicine
# 8       1003122813        PHYSICIANS (FFS)  Emergency Medicine (Urgent Care)
# 10      1003123670        PHYSICIANS (FFS)                   Family Practice
# 12      1003126327        PHYSICIANS (FFS)                  General Practice
# 18      1003127234        PHYSICIANS (FFS)                    Anesthesiology
# 19      1003127242        PHYSICIANS (FFS)                 Internal Medicine
# 20      1003127846        PHYSICIANS (FFS)                 Internal Medicine
# 22      1003127986        PHYSICIANS (FFS)                 Internal Medicine
# 23      1003128323        PHYSICIANS (FFS)                    Anesthesiology
# 24      1003128364        PHYSICIANS (FFS)  Emergency Medicine (Urgent Care)
#
#    Provider_Address_County_Code_De  Provider_Address_Latitude  \
# 3                         Humboldt                  40.783220
# 8                       Stanislaus                  37.706404
# 10                     Los Angeles                  34.098161
# 12                   San Francisco                  37.763821
# 18                          Orange                  33.847152
# 19                        Monterey                  36.576426
# 20                     Santa Clara                  37.433373
# 22                     Santa Clara                  37.239456
# 23                     Los Angeles                  34.076824
# 24                         Alameda                  37.697452
#
#     Provider_Address_Longitude
# 3                  -124.142048
# 8                  -121.050079
# 10                 -118.292966
# 12                 -122.456707
# 18                 -117.933932
# 19                 -121.913993
# 20                 -122.177575
# 22                 -121.802937
# 23                 -118.380276
# 24                 -122.087053

# %%
targetGroups_df = targetGroups_df.rename(columns={"Provider_Number": "Provider",
                                                "Provider_Type_Code_Desc": "Provider_Type",
                                                "Provider_Specialty_Code_Desc": "Specialty",
                                                "Provider_Address_County_Code_De": "County_Code"
                                                })
targetGroups_df.head()
# Out:
#       Provider     Provider_Type                         Specialty  \
# 3   1003121930  PHYSICIANS (FFS)                 Internal Medicine
# 8   1003122813  PHYSICIANS (FFS)  Emergency Medicine (Urgent Care)
# 10  1003123670  PHYSICIANS (FFS)                   Family Practice
# 12  1003126327  PHYSICIANS (FFS)                  General Practice
# 18  1003127234  PHYSICIANS (FFS)                    Anesthesiology
#
#       County_Code  Provider_Address_Latitude  Provider_Address_Longitude
# 3        Humboldt                  40.783220                 -124.142048
# 8      Stanislaus                  37.706404                 -121.050079
# 10    Los Angeles                  34.098161                 -118.292966
# 12  San Francisco                  37.763821                 -122.456707
# 18         Orange                  33.847152                 -117.933932

# %%
targetCounts = targetGroups_df.value_counts('County_Code', sort=False)

# %%
m = targetCounts.median()
m
# Out:
# 558.0

# %%
m = targetCounts.mean()
m
# Out:
# 2496.7758620689656

# %%
targetsGrouped_df = targetGroups_df.groupby('County_Code').agg({'Provider_Address_Latitude':'mean', 'Provider_Address_Longitude':'mean'})
targetsGrouped_df.head()
# Out:
#              Provider_Address_Latitude  Provider_Address_Longitude
# County_Code
# Alameda                      37.742428                 -122.155974
# Alpine                       38.769184                 -119.815993
# Amador                       38.355900                 -120.767838
# Butte                        39.680714                 -121.731512
# Calaveras                    38.171025                 -120.626371

# %%
gmaps.configure(api_key=g_key)

fig = gmaps.figure()

# %%
locations = targetsGrouped_df[["Provider_Address_Latitude", "Provider_Address_Longitude"]].astype(float)

heat_layer = gmaps.heatmap_layer(locations, weights=targetCounts, 
                                 dissipating=False, max_intensity=3000,
                                 point_radius = .5)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
