# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

# %%
caproviderdata = pd.read_csv("Enrolled_Medi-Cal_Fee_For_Service_Provider_File.csv", low_memory=False)
caprovider_df = pd.DataFrame(caproviderdata)

# "C:\Users\Kdw86\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (2) have mixed types.
# Specify dtype option on import or set low_memory=False.
# has_raised = await self.run_ast_nodes(code_ast.body, cell_name,"

#after warning check and toss invalid numbers (with alphas)
#for i, row in caprovider_df.iterrows():
#    try:
#        row['Provider_Number'] = int(row['Provider_Number'])
#    except:
#        caprovider_df.drop(i, inplace=True)

#caprovider_df.dropna(inplace=True)
#caprovider_df.reset_index(drop=True, inplace=True) 



caprovider_df.head()
# Out:
#             X          Y Provider_Number  NPI_Provider_Number  Owner_Number  \
# 0 -117.370428  34.133257      1003120452         1.003120e+09           1.0
# 1 -117.152090  32.884362      1003121385         1.003121e+09           1.0
# 2 -118.744681  34.288645      1003207002         1.003207e+09           1.0
# 3 -124.142048  40.783220      1003121930         1.003122e+09           1.0
# 4 -117.306377  33.181302      1003122086         1.003122e+09           1.0
#
#    Service_Location_Number           Provider_Legal_Name  \
# 0                      1.0     PETERSON, KIMBERLY OD INC
# 1                      1.0  COUNTRYWIDE MEDICAL SUPPLIES
# 2                      2.0       CHANGE WITHIN REACH INC
# 3                      1.0               ALHARIRI, AHMAD
# 4                      1.0                POLLACK, AARON
#
#   Enrollment_Status_Effective_Dat  Provider_Type_Code  \
# 0          2010/08/02 07:00:00+00                  20
# 1          2011/07/05 07:00:00+00                   2
# 2          2018/07/23 07:00:00+00                  71
# 3          2018/11/27 08:00:00+00                  26
# 4          2010/10/19 07:00:00+00                  13
#
#                              Provider_Type_Code_Desc  ...  \
# 0                                 OPTOMETRISTS (FFS)  ...
# 1  ASSISTIVE DEVICE AND SICK ROOM SUPPLY DEALERS ...  ...
# 2        LICENSED CLINICAL SOCIAL WORKER GROUP (FFS)  ...
# 3                                   PHYSICIANS (FFS)  ...
# 4                       HEARING AID DISPENSERS (FFS)  ...
#
#   Provider_Address_Line_2 Provider_Address_City Provider_Address_State  \
# 0               SUITE 100                RIALTO                     CA
# 1             SUITE 5300A             SAN DIEGO                     CA
# 2                  STE 24           SIMI VALLEY                     CA
# 3                     NaN                EUREKA                     CA
# 4                     NaN             OCEANSIDE                     CA
#
#    Provider_Address_Zip Provider_Address_Latitude  Provider_Address_Longitude  \
# 0             923768071                 34.133257                 -117.370428
# 1             921264240                 32.884362                 -117.152090
# 2             930651224                 34.288645                 -118.744681
# 3             955014736                 40.783220                 -124.142048
# 4             920564522                 33.181302                 -117.306377
#
#   MSSA_ID Tract_ID             File_ ObjectId
# 0    151h    38.01  Fee-for-Service         1
# 1    161o    94.00  Fee-for-Service         2
# 2    240a    79.03  Fee-for-Service         3
# 3      39     6.00  Fee-for-Service         4
# 4    156b   185.17  Fee-for-Service         5
#
# [5 rows x 29 columns]

# %%
#caprovider_df = caprovider_df.drop(columns=['X', 'Y', "NPI_Provider_Number", "Owner_Number", 'Provider_Address_Zip',
                                           # "Service_Location_Number", "Provider_Legal_Name", 
                                            #"Provider_Type_Code", "Provider_Type_Code_Desc", "Provider_License_Number",
                                            #"Provider_Specialty_Code", "Out_Of_State_Ind", "Out_Of_State_Desc", 
                                            #"Provider_Address_County_Code", "Provider_Address_Attention_Line", 
                                            #"Provider_Address_Line_1", "Provider_Address_Line_2", "Provider_Address_State", 
                                            #"MSSA_ID","Tract_ID", "File_", "Provider_Address_Latitude", "Provider_Address_Longitude", "ObjectId"])
caprovider_df.head()
# Out:
#      Provider                                      Provider_Type  \
# 0  1003120452                                 OPTOMETRISTS (FFS)
# 1  1003121385  ASSISTIVE DEVICE AND SICK ROOM SUPPLY DEALERS ...
# 2  1003207002        LICENSED CLINICAL SOCIAL WORKER GROUP (FFS)
# 3  1003121930                                   PHYSICIANS (FFS)
# 4  1003122086                       HEARING AID DISPENSERS (FFS)
#
#            Specialty     County_Code
# 0     NOT APPLICABLE  San Bernardino
# 1     NOT APPLICABLE       San Diego
# 2     NOT APPLICABLE         Ventura
# 3  Internal Medicine        Humboldt
# 4     NOT APPLICABLE       San Diego

# %%
caprovider_df = caprovider_df.drop(columns=['X', 'Y', "NPI_Provider_Number", "Owner_Number", 'Provider_Address_Zip',
                                            "Service_Location_Number", "Provider_Legal_Name", 
                                            "Provider_Type_Code", "Provider_License_Number",
                                            "Provider_Specialty_Code", "Out_Of_State_Ind", "Out_Of_State_Desc", 
                                            "Provider_Address_County_Code", "Provider_Address_Attention_Line", 
                                            "Provider_Address_Line_1", "Provider_Address_Line_2", "Provider_Address_State", 
                                            "MSSA_ID","Tract_ID", "File_", "Provider_Address_Latitude", "Provider_Address_Longitude", 
                                            "ObjectId","Enrollment_Status_Effective_Dat","Provider_Address_City"])

caprovider_df.head()
# Out:
#   Provider_Number                            Provider_Type_Code_Desc  \
# 0      1003120452                                 OPTOMETRISTS (FFS)
# 1      1003121385  ASSISTIVE DEVICE AND SICK ROOM SUPPLY DEALERS ...
# 2      1003207002        LICENSED CLINICAL SOCIAL WORKER GROUP (FFS)
# 3      1003121930                                   PHYSICIANS (FFS)
# 4      1003122086                       HEARING AID DISPENSERS (FFS)
#
#   Provider_Specialty_Code_Desc Provider_Address_County_Code_De
# 0               NOT APPLICABLE                  San Bernardino
# 1               NOT APPLICABLE                       San Diego
# 2               NOT APPLICABLE                         Ventura
# 3            Internal Medicine                        Humboldt
# 4               NOT APPLICABLE                       San Diego

# %%
caprovider_df.dtypes
# Out:
# Provider_Number                    object
# Provider_Type_Code_Desc            object
# Provider_Specialty_Code_Desc       object
# Provider_Address_County_Code_De    object
# dtype: object

# %%
targetGroups_df = caprovider_df.loc[(caprovider_df["Provider_Type_Code_Desc"] == "PHYSICIANS GROUP (FFS)") | (caprovider_df["Provider_Type_Code_Desc"] == "PHYSICIANS (FFS)")]

targetGroups_df.head(10)
# Out:
#    Provider_Number Provider_Type_Code_Desc      Provider_Specialty_Code_Desc  \
# 3       1003121930        PHYSICIANS (FFS)                 Internal Medicine
# 8       1003122813        PHYSICIANS (FFS)  Emergency Medicine (Urgent Care)
# 10      1003123670        PHYSICIANS (FFS)                   Family Practice
# 12      1003126327        PHYSICIANS (FFS)                  General Practice
# 18      1003127234        PHYSICIANS (FFS)                    Anesthesiology
# 19      1003127242        PHYSICIANS (FFS)                 Internal Medicine
# 20      1003127846        PHYSICIANS (FFS)                 Internal Medicine
# 21      1003127903        PHYSICIANS (FFS)                               NaN
# 22      1003127986        PHYSICIANS (FFS)                 Internal Medicine
# 23      1003128323        PHYSICIANS (FFS)                    Anesthesiology
#
#    Provider_Address_County_Code_De
# 3                         Humboldt
# 8                       Stanislaus
# 10                     Los Angeles
# 12                   San Francisco
# 18                          Orange
# 19                        Monterey
# 20                     Santa Clara
# 21                         UNKNOWN
# 22                     Santa Clara
# 23                     Los Angeles

# %%
caprovider_df = caprovider_df.rename(columns={"Provider_Number": "Provider",
                                                "Provider_Type_Code_Desc": "Provider_Type",
                                                "Provider_Specialty_Code_Desc": "Specialty",
                                                "Provider_Address_County_Code_De": "County_Code"
                                                })
caprovider_df.head
# Out:
# <bound method NDFrame.head of           Provider                                      Provider_Type  \
# 0       1003120452                                 OPTOMETRISTS (FFS)
# 1       1003121385  ASSISTIVE DEVICE AND SICK ROOM SUPPLY DEALERS ...
# 2       1003207002        LICENSED CLINICAL SOCIAL WORKER GROUP (FFS)
# 3       1003121930                                   PHYSICIANS (FFS)
# 4       1003122086                       HEARING AID DISPENSERS (FFS)
# ...            ...                                                ...
# 250562         NaN                   CERTIFIED NURSE PRACTIONER (FFS)
# 250563         NaN                                            Unknown
# 250564         NaN                                            Unknown
# 250565         NaN                   CERTIFIED NURSE PRACTIONER (FFS)
# 250566         NaN                                            Unknown
#
#                 Specialty     County_Code
# 0          NOT APPLICABLE  San Bernardino
# 1          NOT APPLICABLE       San Diego
# 2          NOT APPLICABLE         Ventura
# 3       Internal Medicine        Humboldt
# 4          NOT APPLICABLE       San Diego
# ...                   ...             ...
# 250562                NaN             NaN
# 250563                NaN             NaN
# 250564                NaN             NaN
# 250565                NaN             NaN
# 250566                NaN             NaN
#
# [250567 rows x 4 columns]>

# %%
pd.set_option("display.max_rows",None)
caprovider_df.groupby("Specialty").count()
# Out:
#                                                     Provider  Provider_Type  \
# Specialty
# Allergy                                                  556            556
# Anesthesiology                                          8267           8267
# Aviation (M.D. only)                                      14             14
# Cardiovascular Disease (M.D. only)                      3649           3649
# Clinic (mixed specialty), Public Health (Dentis...       467            467
# Dentists (DMD)                                             4              4
# Dermatology                                             1833           1833
# Emergency Medicine (Urgent Care)                       12315          12315
# Endocrinology                                            897            897
# Family Practice                                        11083          11083
# Full-Time Facility (Dentists Only)                         1              1
# Gastroenterology (M.D. only), Oral Surgeon (Den...      2101           2101
# General Practice                                       11216          11216
# General Surgery                                         5131           5131
# Geriatrics                                               540            540
# Gynecology (D.O. only)                                   227            227
# Hand Surgery                                             134            134
# Hematology                                              1622           1622
# Infectious Disease                                       950            950
# Internal Medicine                                      26343          26343
# Licensed clinical social worker                            1              1
# Manipulative Therapy (D.O. only)                          16             16
# Marriage, family and child counselor                       1              1
# Miscellaneous                                            205            205
# NOT APPLICABLE                                         52035          52035
# Neoplastic Diseases/Oncology                            2365           2365
# Nephrology (Renal-Kidney)                               1516           1516
# Neurological Surgery                                    1016           1016
# Neurology (M.D. only)                                   2662           2662
# Neurology-Child                                          248            248
# Nuclear Medicine                                         300            300
# Obstetrics (D.O. only), Endodontist (Dentists O...       334            334
# Obstetrics-Gynecology (M.D. Only) Neonatal              6935           6935
# Ophthalmology                                           3608           3608
# Ophthalmology, Otolaryngology, Rhinology (D.O.o...       321            321
# Oral Pathologist (Dentists Only)                           5              5
# Orthopedic Surgery, Orthodontist (Dentists Only)        3723           3723
# Otology, Laryngology, Rhinology                         1263           1263
# Pathologic Anatomy: Clinical Pathology (D.O. only)       174            174
# Pathology (M.D. only)                                   2099           2099
# Pathology-Forensic                                        75             75
# Pediatric Allergy                                         36             36
# Pediatric Cardiology (M.D. only)                         387            387
# Pediatrics, Periodontist (Dentists Only)               12884          12884
# Peripheral Vascular Disease or Surgery (D.O. only)        65             65
# Pharmacology-Clinical                                      5              5
# Physical Medicine and Rehabilitation, Certified...      1090           1090
# Plastic Surgery                                          842            842
# Preventive (M.D. only)                                    45             45
# Proctology (colon and rectal)                             87             87
# Prosthodontist (Dentists Only)                             1              1
# Psychiatry                                              3677           3677
# Psychiatry (child)                                       275            275
# Psychiatry Neurology (D.O. only)                         144            144
# Public Health                                             17             17
# Pulmonary Diseases (M.D. only)                          1661           1661
# Radiation Therapy (D.O. only)                             47             47
# Radiology, Pedodontist (Dentists Only)                  7781           7781
# Registered nurse                                           2              2
# Rheumatology                                             662            662
# Roentgenology, Radiology (M.D. only)                      34             34
# Surgery-Head and Neck                                    291            291
# Surgery-Pediatric                                        131            131
# Surgery-Traumatic                                        192            192
# Thoracic Surgery                                         682            682
# Unknown                                                   66             66
# Urology and Urological Surgery                          1622           1622
#
#                                                     County_Code
# Specialty
# Allergy                                                     556
# Anesthesiology                                             8267
# Aviation (M.D. only)                                         14
# Cardiovascular Disease (M.D. only)                         3649
# Clinic (mixed specialty), Public Health (Dentis...          467
# Dentists (DMD)                                                4
# Dermatology                                                1833
# Emergency Medicine (Urgent Care)                          12315
# Endocrinology                                               897
# Family Practice                                           11083
# Full-Time Facility (Dentists Only)                            1
# Gastroenterology (M.D. only), Oral Surgeon (Den...         2101
# General Practice                                          11216
# General Surgery                                            5131
# Geriatrics                                                  540
# Gynecology (D.O. only)                                      227
# Hand Surgery                                                134
# Hematology                                                 1622
# Infectious Disease                                          950
# Internal Medicine                                         26343
# Licensed clinical social worker                               1
# Manipulative Therapy (D.O. only)                             16
# Marriage, family and child counselor                          1
# Miscellaneous                                               205
# NOT APPLICABLE                                            52035
# Neoplastic Diseases/Oncology                               2365
# Nephrology (Renal-Kidney)                                  1516
# Neurological Surgery                                       1016
# Neurology (M.D. only)                                      2662
# Neurology-Child                                             248
# Nuclear Medicine                                            300
# Obstetrics (D.O. only), Endodontist (Dentists O...          334
# Obstetrics-Gynecology (M.D. Only) Neonatal                 6935
# Ophthalmology                                              3608
# Ophthalmology, Otolaryngology, Rhinology (D.O.o...          321
# Oral Pathologist (Dentists Only)                              5
# Orthopedic Surgery, Orthodontist (Dentists Only)           3723
# Otology, Laryngology, Rhinology                            1263
# Pathologic Anatomy: Clinical Pathology (D.O. only)          174
# Pathology (M.D. only)                                      2099
# Pathology-Forensic                                           75
# Pediatric Allergy                                            36
# Pediatric Cardiology (M.D. only)                            387
# Pediatrics, Periodontist (Dentists Only)                  12884
# Peripheral Vascular Disease or Surgery (D.O. only)           65
# Pharmacology-Clinical                                         5
# Physical Medicine and Rehabilitation, Certified...         1090
# Plastic Surgery                                             842
# Preventive (M.D. only)                                       45
# Proctology (colon and rectal)                                87
# Prosthodontist (Dentists Only)                                1
# Psychiatry                                                 3677
# Psychiatry (child)                                          275
# Psychiatry Neurology (D.O. only)                            144
# Public Health                                                17
# Pulmonary Diseases (M.D. only)                             1661
# Radiation Therapy (D.O. only)                                47
# Radiology, Pedodontist (Dentists Only)                     7781
# Registered nurse                                              2
# Rheumatology                                                662
# Roentgenology, Radiology (M.D. only)                         34
# Surgery-Head and Neck                                       291
# Surgery-Pediatric                                           131
# Surgery-Traumatic                                           192
# Thoracic Surgery                                            682
# Unknown                                                      66
# Urology and Urological Surgery                             1622
