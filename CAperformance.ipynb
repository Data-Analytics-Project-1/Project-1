# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
caperformdata = pd.read_csv("dataset-indicator-performance-california-year-2016-2018.csv")
caperform_df = pd.DataFrame(caperformdata)
caperform_df.dropna(inplace=True)
caperform_df.reset_index(drop=True, inplace=True)
caperform_df.head(10)
# Out:
#                                            Indicator  \
# 0                        Uninsured adults ages 19–64
# 1                       Uninsured children ages 0–18
# 2  Hospital admissions for pediatric asthma, per ...
# 3  Adults age 18 and older who went without care ...
# 4  Adults age 18 and older with a usual source of...
# 5  Adults age 18 and older without a dental visit...
# 6  Adults with age- and gender-appropriate cancer...
# 7               Adults with age-appropriate vaccines
# 8   Adults ages 18–64 who report fair or poor health
# 9                 Adults ages 18 and older who smoke
#
#                                               Source   2016   2017   2018
# 0  American Community Survey, Public Use Microdat...  10.4%  10.2%  10.1%
# 1  American Community Survey, Public Use Microdat...   3.2%   3.2%   3.1%
# 2  Healthcare Cost and Utilization Project (HCUP)...      -      -      -
# 3  Behavioral Risk Factor Surveillance System (BR...    11%    12%    12%
# ...
