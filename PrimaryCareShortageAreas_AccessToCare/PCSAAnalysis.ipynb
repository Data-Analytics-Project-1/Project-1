# %%
import pandas as pd
import gmaps
import matplotlib.pyplot as plt
from scipy.stats import linregress

from config import g_key

# %%
latlng_df = pd.DataFrame(pd.read_csv("Data/CenPop2010CountyCenters.csv"))
latlng_df.head()
# Out:
#    STATEFP  COUNTYFP    COUNAME      STNAME  POPULATION   LATITUDE   LONGITUDE
# 0        6         1    Alameda  California     1510271  37.705201 -122.100393
# 1        6         3     Alpine  California        1175  38.728298 -119.847603
# 2        6         5     Amador  California       38091  38.394208 -120.775729
# 3        6         7      Butte  California      220000  39.669037 -121.707635
# 4        6         9  Calaveras  California       45578  38.163627 -120.633718

# %%
PCSA_df = pd.DataFrame(pd.read_csv("Data/Primary_Care_Shortage_Areas_(PCSA).csv"))
PCSA_df.head()
# Out:
#    OBJECTID  UNIT_COUNT  CNTY_FIPS   COUNTY MSSA_ID  \
# 0         1          11          1  Alameda     1.1
# 1         2           8          1  Alameda     1.2
# 2         3          12          7    Butte      10
# 3         4           1         49    Modoc     100
# 4         5           2         51     Mono     102
#
#                                            MSSA_NAME DEFINITION   POPDENSITY  \
# 0             Livermore Central and West/Spring Town      Urban  1752.000139
# 1  Altamont/Livermore East/Midway/Mountain House/...      Rural   116.545153
# 2                        Oroville/Palermo/Thermalito      Rural   175.468375
# 3                                Adin/Lookout/Newell   Frontier     2.315574
# 4  Benton/Bridgeport/Chalfant/Crowley Lake/Colevi...   Frontier     1.957937
#
#      AREA_SQMI    POP  PCSA  PCSA_SCORE  PC_PHYS  PC_PHYS_R_CIV  POVScore  \
# 0     0.472102  43860     0           2     48.0    1186.104167         1
# 1     1.950268  32480     1           6     12.0    3167.333333         1
# 2     7.768868  42656     1           5     34.0    1408.352941         4
# 3   956.134376   1454     1           7      0.0       0.000000         2
# 4  1452.267904   5343     1           6      1.0    5951.000000         1
#
#    PHYSRatioScore  Shape__Area  Shape__Length
# 0               1     0.008283       0.489279
# 1               5     0.086298       1.651976
# 2               1     0.075224       1.615445
# 3               5     0.267075       3.281548
# 4               5     0.813804       5.793963

# %%
PCSA_df.drop(columns=['OBJECTID','CNTY_FIPS','DEFINITION','MSSA_NAME','Shape__Area','UNIT_COUNT', 'POVScore',
'Shape__Length','PC_PHYS_R_CIV', 'MSSA_ID', 'POPDENSITY', 'AREA_SQMI', 'POP', 'PCSA', 'PC_PHYS', 'PCSA_SCORE'], inplace=True)
PCSA_df = PCSA_df.loc[PCSA_df['PHYSRatioScore'].isnull().values == False]

PCSA_df.head()
# Out:
#     COUNTY  PHYSRatioScore
# 0  Alameda               1
# 1  Alameda               5
# 2    Butte               1
# 3    Modoc               5
# 4     Mono               5

# %%
PCSA_merged_df = PCSA_df.merge(latlng_df, how='outer', left_on=PCSA_df['COUNTY'] , right_on=latlng_df['COUNAME'])
PCSA_merged_df.head()
# Out:
#      key_0   COUNTY  PHYSRatioScore  STATEFP  COUNTYFP  COUNAME      STNAME  \
# 0  Alameda  Alameda               1        6         1  Alameda  California
# 1  Alameda  Alameda               5        6         1  Alameda  California
# 2  Alameda  Alameda               0        6         1  Alameda  California
# 3  Alameda  Alameda               0        6         1  Alameda  California
# 4  Alameda  Alameda               0        6         1  Alameda  California
#
#    POPULATION   LATITUDE   LONGITUDE
# 0     1510271  37.705201 -122.100393
# 1     1510271  37.705201 -122.100393
# 2     1510271  37.705201 -122.100393
# 3     1510271  37.705201 -122.100393
# 4     1510271  37.705201 -122.100393

# %%
PCSA_merged_df.drop(columns=['key_0', 'STATEFP', 'COUNTYFP','STNAME', 'POPULATION', 'COUNAME'], inplace=True)
PCSA_merged_df.head()
# Out:
#     COUNTY  PHYSRatioScore   LATITUDE   LONGITUDE
# 0  Alameda               1  37.705201 -122.100393
# 1  Alameda               5  37.705201 -122.100393
# 2  Alameda               0  37.705201 -122.100393
# 3  Alameda               0  37.705201 -122.100393
# 4  Alameda               0  37.705201 -122.100393

# %%
PCSA_merged_df = PCSA_merged_df.groupby('COUNTY').agg({'PHYSRatioScore':'median', 'LATITUDE':'mean',
                                            'LONGITUDE': 'mean'})
PCSA_merged_df.head(10)
# Out:
#               PHYSRatioScore   LATITUDE   LONGITUDE
# COUNTY
# Alameda                  0.5  37.705201 -122.100393
# Alpine                   5.0  38.728298 -119.847603
# Amador                   2.0  38.394208 -120.775729
# Butte                    1.5  39.669037 -121.707635
# Calaveras                2.0  38.163627 -120.633718
# Colusa                   5.0  39.156148 -122.085557
# Contra Costa             1.0  37.935588 -122.030131
# Del Norte                0.0  41.791232 -124.163088
# El Dorado                3.0  38.746543 -120.744330
# Fresno                   5.0  36.738918 -119.767884

# %%
gmaps.configure(api_key=g_key)

fig = gmaps.figure()

# %%
#Heatmap of Median Physician Ratio Score By County

locations = PCSA_merged_df[["LATITUDE", "LONGITUDE"]].astype(float)

heat_layer = gmaps.heatmap_layer(locations, weights= PCSA_merged_df['PHYSRatioScore'],
                                 dissipating=False, max_intensity=8.5,
                                 point_radius = .7)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
feeding_america_df = pd.read_csv('Data/Feeding-America-Projections-March 2021-Food-Insecurity.csv')
feeding_america_df = feeding_america_df.loc[feeding_america_df['State'] == 'CA']
feeding_america_df['COUNTY'] = feeding_america_df['County, State'].str.split(',').str[0]
feeding_america_df['COUNTY'] = feeding_america_df['COUNTY'].str.split(' ').str[0]
feeding_america_df.set_index('COUNTY', inplace=True)

feeding_america_df.head()
# Out:
#                           County, State  FIPS State  Total Population  \
# COUNTY
# Alameda      Alameda County, California  6001    CA           1656754
# Alpine        Alpine County, California  6003    CA              1039
# Amador        Amador County, California  6005    CA             38429
# Butte          Butte County, California  6007    CA            225817
# Calaveras  Calaveras County, California  6009    CA             45514
#
#            2019 Food Insecurity %  2019 Food Insecurity #  \
# COUNTY
# Alameda                     0.084                  139810
# Alpine                      0.131                     140
# Amador                      0.107                    4120
# Butte                       0.144                   32450
# Calaveras                   0.118                    5360
#
#            [Revised Projections – March 2021]\n2020 Food Insecurity  %  \
# COUNTY
# Alameda                                                0.122
# Alpine                                                 0.173
# Amador                                                 0.142
# Butte                                                  0.172
# Calaveras                                              0.146
#
#            [Revised Projections – March 2021]\n2020 Food Insecurity #  \
# COUNTY
# Alameda                                               201870
# Alpine                                                   180
# Amador                                                  5460
# Butte                                                  38840
# Calaveras                                               6660
#
#            [Revised Projections – March 2021]\n2020 Food Insecurity % Change  \
# COUNTY
# Alameda                                                   44
# Alpine                                                    32
# Amador                                                    32
# Butte                                                     20
# Calaveras                                                 24
#
#            [Revised Projections – March 2021]\n2020 Food Insecurity # Change  \
# COUNTY
# Alameda                                                62060
# Alpine                                                    40
# Amador                                                  1340
# Butte                                                   6390
# Calaveras                                               1290
#
#            [Revised Projections – March 2021]\nAdjusted Annual Unemployment Change  \
# COUNTY
# Alameda                                                  5.9
# Alpine                                                   6.8
# Amador                                                   5.4
# Butte                                                    4.1
# Calaveras                                                4.1
#
#            Total Child Population  2019 Child Food Insecurity  %  \
# COUNTY
# Alameda                    344027                          0.099
# Alpine                        201                          0.194
# Amador                       5847                          0.161
# Butte                       45439                          0.187
# Calaveras                    7811                          0.187
#
#            2019 Child Food Insecurity #  \
# COUNTY
# Alameda                           34040
# Alpine                               40
# Amador                              940
# Butte                              8510
# Calaveras                          1460
#
#            [Revised Projections – March 2021]\n2020 Child Food Insecurity  %  \
# COUNTY
# Alameda                                                0.166
# Alpine                                                 0.271
# Amador                                                 0.224
# Butte                                                  0.238
# Calaveras                                              0.238
#
#            [Revised Projections – March 2021]\n2020 Child Food Insecurity #  \
# COUNTY
# Alameda                                                57240
# Alpine                                                    50
# Amador                                                  1310
# Butte                                                  10800
# Calaveras                                               1860
#
#            [Revised Projections – March 2021]\n2020 Child Food Insecurity % Change  \
# COUNTY
# Alameda                                                   68
# Alpine                                                    39
# Amador                                                    39
# Butte                                                     27
# Calaveras                                                 27
#
#            [Revised Projections – March 2021]\n2020 Child Food Insecurity # Change
# COUNTY
# Alameda                                                23200
# Alpine                                                    20
# Amador                                                   370
# Butte                                                   2290
# Calaveras                                                390

# %%
PCSA_FA_df = feeding_america_df.merge(PCSA_merged_df, right_index=True, left_index=True)
PCSA_FA_df.head()
# Out:
#                           County, State  FIPS State  Total Population  \
# COUNTY
# Alameda      Alameda County, California  6001    CA           1656754
# Alpine        Alpine County, California  6003    CA              1039
# Amador        Amador County, California  6005    CA             38429
# Butte          Butte County, California  6007    CA            225817
# Calaveras  Calaveras County, California  6009    CA             45514
#
#            2019 Food Insecurity %  2019 Food Insecurity #  \
# COUNTY
# Alameda                     0.084                  139810
# Alpine                      0.131                     140
# Amador                      0.107                    4120
# Butte                       0.144                   32450
# Calaveras                   0.118                    5360
#
#            [Revised Projections – March 2021]\n2020 Food Insecurity  %  \
# COUNTY
# Alameda                                                0.122
# Alpine                                                 0.173
# Amador                                                 0.142
# Butte                                                  0.172
# Calaveras                                              0.146
#
#            [Revised Projections – March 2021]\n2020 Food Insecurity #  \
# COUNTY
# Alameda                                               201870
# Alpine                                                   180
# Amador                                                  5460
# Butte                                                  38840
# Calaveras                                               6660
#
#            [Revised Projections – March 2021]\n2020 Food Insecurity % Change  \
# COUNTY
# Alameda                                                   44
# Alpine                                                    32
# Amador                                                    32
# Butte                                                     20
# Calaveras                                                 24
#
#            [Revised Projections – March 2021]\n2020 Food Insecurity # Change  \
# COUNTY
# Alameda                                                62060
# Alpine                                                    40
# Amador                                                  1340
# Butte                                                   6390
# Calaveras                                               1290
#
#            ...  Total Child Population  2019 Child Food Insecurity  %  \
# COUNTY     ...
# Alameda    ...                  344027                          0.099
# Alpine     ...                     201                          0.194
# Amador     ...                    5847                          0.161
# Butte      ...                   45439                          0.187
# Calaveras  ...                    7811                          0.187
#
#            2019 Child Food Insecurity #  \
# COUNTY
# Alameda                           34040
# Alpine                               40
# Amador                              940
# Butte                              8510
# Calaveras                          1460
#
#            [Revised Projections – March 2021]\n2020 Child Food Insecurity  %  \
# COUNTY
# Alameda                                                0.166
# Alpine                                                 0.271
# Amador                                                 0.224
# Butte                                                  0.238
# Calaveras                                              0.238
#
#            [Revised Projections – March 2021]\n2020 Child Food Insecurity #  \
# COUNTY
# Alameda                                                57240
# Alpine                                                    50
# Amador                                                  1310
# Butte                                                  10800
# Calaveras                                               1860
#
#            [Revised Projections – March 2021]\n2020 Child Food Insecurity % Change  \
# COUNTY
# Alameda                                                   68
# Alpine                                                    39
# Amador                                                    39
# Butte                                                     27
# Calaveras                                                 27
#
#            [Revised Projections – March 2021]\n2020 Child Food Insecurity # Change  \
# COUNTY
# Alameda                                                23200
# Alpine                                                    20
# Amador                                                   370
# Butte                                                   2290
# Calaveras                                                390
#
#            PHYSRatioScore   LATITUDE   LONGITUDE
# COUNTY
# Alameda               0.5  37.705201 -122.100393
# Alpine                5.0  38.728298 -119.847603
# Amador                2.0  38.394208 -120.775729
# Butte                 1.5  39.669037 -121.707635
# Calaveras             2.0  38.163627 -120.633718
#
# [5 rows x 21 columns]
