# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
serviceAreas_df = pd.DataFrame(pd.read_csv("MSSA_Detail.csv"))
serviceAreas_df.head()
# Out:
#    OBJECTID   TRACT  STATE_FIPS  CNTY_FIPS  TRACT_CODE  CENSUS_KEY  \
# 0         1  4427.0           6          1      442700  6001442700
# 1         2  4428.0           6          1      442800  6001442800
# 2         3  2049.2           6         37      204920  6037204920
# 3         4  2051.1           6         37      205110  6037205110
# 4         5  2051.2           6         37      205120  6037205120
#
#         COUNTY  TRACT_ID MSSA_ID  \
# 0      Alameda    4427.0      2i
# 1      Alameda    4428.0      2i
# 2  Los Angeles    2049.2   78.2h
# 3  Los Angeles    2051.1   78.2h
# 4  Los Angeles    2051.2   78.2h
#
#                                            MSSA_NAME  ...  AGE_18_64  \
# 0  Fremont South/Mission San Jose/Newark South/Wa...  ...       1920
# 1  Fremont South/Mission San Jose/Newark South/Wa...  ...       2035
# 2            Boyle Heights Central/City Terrace West  ...       1580
# 3            Boyle Heights Central/City Terrace West  ...       2097
# 4            Boyle Heights Central/City Terrace West  ...       2154
#
#    PCT_18_64  AGE_65OVER  PCT_65OVER  ELD_RATIO  YTH_RATIO  Shape_STArea_1  \
# 0  60.797973         491   15.547815   0.085366   0.182927               0
# 1  65.245271         419   13.433793   0.296117   0.475728               0
# 2  61.936495         272   10.662485   0.209726   0.924012               0
# 3  58.970754         168    4.724409   0.138821   0.888206               0
# 4  61.666190         286    8.187804   0.286744   0.670029               0
#
#    Shape_STLength_1   Shape__Area  Shape__Length
# 0                 0  1.234033e+06    4764.916655
# 1                 0  1.278647e+06    4762.049318
# 2                 0  9.099753e+05    3900.202320
# 3                 0  2.869607e+05    2813.128371
# 4                 0  1.466126e+06    6115.674007
#
# [5 rows x 62 columns]

# %%
serviceAreas_df.drop(columns=['OBJECTID', 'STATE_FIPS', 'MSSA_ID', 'TRACT_ID', 'TRACT_CODE', 'TRACT', 'CENSUS_KEY', 'COUNTY',
                             'MSSA_NAME', 'Shape_STArea_1', 'Shape_STLength_1', 'Shape__Area', 'Shape__Length'], inplace=True)
serviceAreas_df.dropna(inplace=True)

serviceAreas_df.head()
# Out:
#    CNTY_FIPS  AREA_SQMI   POP  POP_CIV  TOTALPOVPOP  POP100POV  PCT100POV  \
# 0          1   0.476463  2459     3158         3158        104        3.3
# 1          1   0.493688  2396     3119         3119        365       11.7
# 2         37   0.351343   103     2551         2551        702       27.5
# 3         37   0.110796   148     3556         3556       1650       46.4
# 4         37   0.566074   146     3493         3493       1358       38.9
#
#    POP200POV  PCT200POV  WHITE  ...  AGE_UNDER5  PCT_UNDER5  AGE_UNDR18  \
# 0        217   6.871438   1774  ...         169    5.533726         747
# 1        874  28.021802   1508  ...         159    5.773420         665
# 2       1602  62.798902   1702  ...          90    4.867496         699
# 3       2939  82.649044   1878  ...         145    7.607555        1291
# 4       2717  77.784140   1754  ...         122    5.714286        1053
#
#    PCT_UNDR18  AGE_18_64  PCT_18_64  AGE_65OVER  PCT_65OVER  ELD_RATIO  \
# 0   23.654212       1920  60.797973         491   15.547815   0.085366
# 1   21.320936       2035  65.245271         419   13.433793   0.296117
# 2   27.401019       1580  61.936495         272   10.662485   0.209726
# 3   36.304837       2097  58.970754         168    4.724409   0.138821
# 4   30.146006       2154  61.666190         286    8.187804   0.286744
#
#    YTH_RATIO
# 0   0.182927
# 1   0.475728
# 2   0.924012
# 3   0.888206
# 4   0.670029
#
# [5 rows x 49 columns]

# %%
serviceAreas_df.columns
# Out:
# Index(['CNTY_FIPS', 'AREA_SQMI', 'POP', 'POP_CIV', 'TOTALPOVPOP', 'POP100POV',
#        'PCT100POV', 'POP200POV', 'PCT200POV', 'WHITE', 'PCT_WHITE',
#        'NHS_WHITE', 'PCT_NHS_WHITE', 'BLACK', 'PCT_BLACK', 'NHS_BLACK',
#        'PCT_NHS_BLACK', 'ASIAN', 'PCT_ASIAN', 'NHS_ASIAN', 'PCT_NHS_ASIAN',
#        'AMIND_ESK', 'PCT_AMIND_ESK', 'NHS_AMIND_ESK', 'PCT_NHS_AMIND_ESK',
#        'ISLANDER', 'PCT_ISLAND', 'NHS_ISLANDER', 'PCT_NHS_ISLANDER',
#        'OTHER_RACE', 'PCT_OTHER', 'NHS_OTHER_RACE', 'PCT_NHS_OTHER_RACE',
#        'MULTI_RACE', 'PCT_MULTI', 'NHS_MULTI_RACE', 'PCT_NHS_MULTI_RACE',
#        'HISPANIC', 'PCT_HSPNC', 'AGE_UNDER5', 'PCT_UNDER5', 'AGE_UNDR18',
#        'PCT_UNDR18', 'AGE_18_64', 'PCT_18_64', 'AGE_65OVER', 'PCT_65OVER',
#        'ELD_RATIO', 'YTH_RATIO'],
#       dtype='object')

# %%
serviceAreas_df = serviceAreas_df.groupby('CNTY_FIPS').agg({'AREA_SQMI':'sum', 'POP':'sum', 'POP_CIV':'sum', 'TOTALPOVPOP':'sum',
                                                           'POP100POV':'sum', 'PCT100POV':'mean', 'POP200POV':'sum', 'PCT200POV':'mean', 
                                                           'WHITE':'sum', 'PCT_WHITE':'mean', 'NHS_WHITE':'sum', 'PCT_NHS_WHITE':'mean',
                                                           'BLACK':'sum', 'PCT_BLACK':'mean', 'NHS_BLACK':'sum', 'PCT_NHS_BLACK':'mean', 
                                                           'ASIAN':'sum', 'PCT_ASIAN':'mean', 'NHS_ASIAN':'sum', 'PCT_NHS_ASIAN':'mean',
                                                           'AMIND_ESK':'sum', 'PCT_AMIND_ESK':'mean', 'NHS_AMIND_ESK':'sum', 
                                                           'PCT_NHS_AMIND_ESK':'mean', 'ISLANDER':'sum', 'PCT_ISLAND':'mean', 
                                                           'NHS_ISLANDER':'sum', 'PCT_NHS_ISLANDER':'mean', 'OTHER_RACE':'sum', 'PCT_OTHER':'mean',
                                                           'NHS_OTHER_RACE':'sum', 'PCT_NHS_OTHER_RACE':'mean', 'MULTI_RACE':'sum', 'PCT_MULTI':'mean', 
                                                           'NHS_MULTI_RACE':'sum', 'PCT_NHS_MULTI_RACE':'mean', 'HISPANIC':'sum', 'PCT_HSPNC':'mean', 
                                                           'AGE_UNDER5':'sum', 'PCT_UNDER5':'mean', 'AGE_UNDR18':'sum', 'PCT_UNDR18':'mean', 
                                                           'AGE_18_64':'sum', 'PCT_18_64':'mean', 'AGE_65OVER':'sum', 'PCT_65OVER':'mean',
                                                           'ELD_RATIO':'mean', 'YTH_RATIO':'mean'})

# %%
serviceAreas_df.head(15)
# Out:
#               AREA_SQMI      POP  POP_CIV  TOTALPOVPOP  POP100POV  PCT100POV  \
# CNTY_FIPS
# 1            743.969228  1206808  1531346      1531346     197191  13.325000
